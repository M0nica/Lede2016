# %%
import config

api_key = config.api_key

api_secret = config.api_secret

access_token = config.access_token

access_secret = config.access_secret

# %%
# !pip3 install twython
# Out:
# Requirement already satisfied (use --upgrade to upgrade): twython in /usr/local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): requests-oauthlib>=0.4.0 in /usr/local/lib/python3.5/site-packages (from twython)
# Requirement already satisfied (use --upgrade to upgrade): requests>=2.1.0 in /usr/local/lib/python3.5/site-packages (from twython)
# Requirement already satisfied (use --upgrade to upgrade): oauthlib>=0.6.2 in /usr/local/lib/python3.5/site-packages (from requests-oauthlib>=0.4.0->twython)

# %%
import twython

# %%
twitter = twython.Twython(api_key, api_secret, access_token, access_secret)

# %%
response = twitter.search(q="data journalism", result_type="recent", count=20)

# %%
response.keys()
# Out:
# dict_keys(['search_metadata', 'statuses'])

# %%
response['search_metadata'].keys()
# Out:
# dict_keys(['max_id_str', 'next_results', 'completed_in', 'query', 'count', 'since_id_str', 'max_id', 'since_id', 'refresh_url'])

# %%
response['statuses']
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 15:06:18 +0000 2016',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'buff.ly/29gI2mi',
#      'expanded_url': 'http://buff.ly/29gI2mi',
#      'indices': [59, 82],
#      'url': 'https://t.co/3vGbN7h3t4'}],
#    'user_mentions': [{'id': 14458280,
#      'id_str': '14458280',
#      'indices': [50, 58],
#      'name': 'HubSpot',
#      'screen_name': 'HubSpot'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750345064757403648,
#   'id_str': '750345064757403648',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#   'text': 'Data Journalism: A Simple Guide for Marketers via @HubSpot https://t.co/3vGbN7h3t4',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Apr 05 11:24:42 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Get relevant Twitter #followers, better #Engagement, and more #Leads with SocialBee’s Twitter Tools and Concierge Services.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'socialbee.io',
#        'expanded_url': 'http://socialbee.io/',
#        'indices': [0, 23],
#        'url': 'https://t.co/BdR9cN6pvj'}]}},
#    'favourites_count': 4,
#    'follow_request_sent': False,
#    'followers_count': 2280,
#    'following': False,
#    'friends_count': 2306,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 717311998552354816,
#    'id_str': '717311998552354816',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 56,
#    'location': '',
#    'name': 'SocialBee',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/717311998552354816/1463586310',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/717312503135473664/II9AuO3K_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/717312503135473664/II9AuO3K_normal.jpg',
#    'profile_link_color': '607D8B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'SocialBeeHQ',
#    'statuses_count': 654,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'url': 'https://t.co/BdR9cN6pvj',
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 15:00:12 +0000 2016',
#   'entities': {'hashtags': [{'indices': [69, 73], 'text': 'ddj'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tinyurl.com/hl5p2dw',
#      'expanded_url': 'http://tinyurl.com/hl5p2dw',
#      'indices': [45, 68],
#      'url': 'https://t.co/62GBDcIhrW'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750343527033294849,
#   'id_str': '750343527033294849',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.postatic.com" rel="nofollow">Postatic</a>',
#   'text': 'Six ways to generate data journalism stories https://t.co/62GBDcIhrW #ddj #',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 23 16:48:46 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'HackerNews for digital journos. New tools, libraries, tips and tutorials + more for interactive storytelling. Submit your URL and vote it up. Info: @carlvlewis.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'newsnerdnews.co',
#        'expanded_url': 'http://newsnerdnews.co',
#        'indices': [0, 22],
#        'url': 'http://t.co/bJsblPcLtp'}]}},
#    'favourites_count': 27,
#    'follow_request_sent': False,
#    'followers_count': 181,
#    'following': False,
#    'friends_count': 278,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 2584271172,
#    'id_str': '2584271172',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 51,
#    'location': 'AWS S3 servers',
#    'name': 'NewsNerdNews.co',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2584271172/1411760247',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/515139422874906624/RLTOyf-__normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/515139422874906624/RLTOyf-__normal.png',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'newsnerdnews',
#    'statuses_count': 13199,
#    'time_zone': None,
#    'url': 'http://t.co/bJsblPcLtp',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:59:37 +0000 2016',
#   'entities': {'hashtags': [{'indices': [71, 77], 'text': 'zucht'}],
#    'media': [{'display_url': 'pic.twitter.com/HtZjaSUleS',
#      'expanded_url': 'http://twitter.com/RuudHouweling/status/750343379742056448/photo/1',
#      'id': 750343166017015808,
#      'id_str': '750343166017015808',
#      'indices': [103, 126],
#      'media_url': 'http://pbs.twimg.com/media/CmnBIk4WEAA9HZY.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/CmnBIk4WEAA9HZY.jpg',
#      'sizes': {'large': {'h': 402, 'resize': 'fit', 'w': 600},
#       'medium': {'h': 402, 'resize': 'fit', 'w': 600},
#       'small': {'h': 402, 'resize': 'fit', 'w': 600},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/HtZjaSUleS'}],
#    'symbols': [],
#    'urls': [{'display_url': 'theguardian.com/news/datablog/…',
#      'expanded_url': 'https://www.theguardian.com/news/datablog/2010/oct/23/wikileaks-iraq-data-journalism',
#      'indices': [79, 102],
#      'url': 'https://t.co/jMCKL4u4As'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750343379742056448,
#   'id_str': '750343379742056448',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'nl',
#   'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Een kaart met daarop locaties van alle ontplofte autobommen in Bagdad. #zucht\n\nhttps://t.co/jMCKL4u4As https://t.co/HtZjaSUleS',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jul 25 17:31:46 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'songwriter l composer l performer, formerly of @cloudmachine, working on solo album',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'ruudhouweling.com',
#        'expanded_url': 'http://ruudhouweling.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/bWmtohOBqE'}]}},
#    'favourites_count': 2292,
#    'follow_request_sent': False,
#    'followers_count': 391,
#    'following': False,
#    'friends_count': 327,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 170753150,
#    'id_str': '170753150',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 17,
#    'location': 'The Netherlands',
#    'name': 'Ruud Houweling',
#    'notifications': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170753150/1451271816',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/678213286421229568/v7O3qDrZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/678213286421229568/v7O3qDrZ_normal.jpg',
#    'profile_link_color': 'B8B8B8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': 'BAB3B3',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'RuudHouweling',
#    'statuses_count': 6869,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'url': 'https://t.co/bWmtohOBqE',
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:44:16 +0000 2016',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/YIIEf3vKd5',
#      'expanded_url': 'http://twitter.com/IE_AnneClaire/status/750145193937145856/photo/1',
#      'id': 750145191516966912,
#      'id_str': '750145191516966912',
#      'indices': [139, 140],
#      'media_url': 'http://pbs.twimg.com/media/CmkNE8ZWEAA8Umy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/CmkNE8ZWEAA8Umy.jpg',
#      'sizes': {'large': {'h': 418, 'resize': 'fit', 'w': 932},
#       'medium': {'h': 418, 'resize': 'fit', 'w': 932},
#       'small': {'h': 305, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 750145193937145856,
#      'source_status_id_str': '750145193937145856',
#      'source_user_id': 4171435624,
#      'source_user_id_str': '4171435624',
#      'type': 'photo',
#      'url': 'https://t.co/YIIEf3vKd5'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/29hYsNN',
#      'expanded_url': 'http://bit.ly/29hYsNN',
#      'indices': [94, 117],
#      'url': 'https://t.co/jToiOpgKxq'}],
#    'user_mentions': [{'id': 4171435624,
#      'id_str': '4171435624',
#      'indices': [3, 17],
#      'name': 'Anne-Claire Herve',
#      'screen_name': 'IE_AnneClaire'},
#     {'id': 162496681,
#      'id_str': '162496681',
#      'indices': [118, 132],
#      'name': 'EuroScientist',
#      'screen_name': 'EuroScientist'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750339518906130432,
#   'id_str': '750339518906130432',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 05 01:52:05 +0000 2016',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/YIIEf3vKd5',
#       'expanded_url': 'http://twitter.com/IE_AnneClaire/status/750145193937145856/photo/1',
#       'id': 750145191516966912,
#       'id_str': '750145191516966912',
#       'indices': [114, 137],
#       'media_url': 'http://pbs.twimg.com/media/CmkNE8ZWEAA8Umy.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CmkNE8ZWEAA8Umy.jpg',
#       'sizes': {'large': {'h': 418, 'resize': 'fit', 'w': 932},
#        'medium': {'h': 418, 'resize': 'fit', 'w': 932},
#        'small': {'h': 305, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/YIIEf3vKd5'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/29hYsNN',
#       'expanded_url': 'http://bit.ly/29hYsNN',
#       'indices': [75, 98],
#       'url': 'https://t.co/jToiOpgKxq'}],
#     'user_mentions': [{'id': 162496681,
#       'id_str': '162496681',
#       'indices': [99, 113],
#       'name': 'EuroScientist',
#       'screen_name': 'EuroScientist'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 750145193937145856,
#    'id_str': '750145193937145856',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': 'Data Journalism Awards celebrate evidence-based questioning in our society https://t.co/jToiOpgKxq @euroscientist https://t.co/YIIEf3vKd5',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Nov 12 13:02:29 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Global Marketing Coordinator',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'theinnovationenterprise.com',
#         'expanded_url': 'http://theinnovationenterprise.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/cWN5Udq7Ls'}]}},
#     'favourites_count': 51,
#     'follow_request_sent': False,
#     'followers_count': 191,
#     'following': False,
#     'friends_count': 295,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 4171435624,
#     'id_str': '4171435624',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 76,
#     'location': 'London, England',
#     'name': 'Anne-Claire Herve',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4171435624/1462878202',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/730003098803044352/9dFlFZYC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/730003098803044352/9dFlFZYC_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'IE_AnneClaire',
#     'statuses_count': 647,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'url': 'https://t.co/cWN5Udq7Ls',
#     'utc_offset': -25200,
#     'verified': False}},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'RT @IE_AnneClaire: Data Journalism Awards celebrate evidence-based questioning in our society https://t.co/jToiOpgKxq @euroscientist https:…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 03 21:17:52 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'European science conversations by the community, for the community  #Research in Europe, #SciencePolicy and #austerity in #science',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'euroscientist.com',
#        'expanded_url': 'http://www.euroscientist.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/zmuotq3nsN'}]}},
#    'favourites_count': 52,
#    'follow_request_sent': False,
#    'followers_count': 3289,
#    'following': False,
#    'friends_count': 1026,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 162496681,
#    'id_str': '162496681',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en-gb',
#    'listed_count': 259,
#    'location': 'Europe',
#    'name': 'EuroScientist',
#    'notifications': False,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/162496681/1467121028',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/699891376746582017/VY93O0Dh_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/699891376746582017/VY93O0Dh_normal.png',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'EuroScientist',
#    'statuses_count': 5896,
#    'time_zone': 'Amsterdam',
#    'url': 'http://t.co/zmuotq3nsN',
#    'utc_offset': 7200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:39:06 +0000 2016',
#   'entities': {'hashtags': [{'indices': [8, 12], 'text': 'ddj'}],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/4Y6GLplOp',
#      'expanded_url': 'http://fb.me/4Y6GLplOp',
#      'indices': [60, 83],
#      'url': 'https://t.co/FuMYXglSWb'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750338219502338053,
#   'id_str': '750338219502338053',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'Top Ten #ddj: The Week’s Most Popular Data Journalism Links https://t.co/FuMYXglSWb',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Nov 05 03:29:19 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '(Social) (media) network analysis and visualization add-in for Excel 2007, 2010, 2013 & 2016. Get NodeXL Pro! http://t.co/AlY9U3Lyfo',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1L0asP7',
#        'expanded_url': 'http://bit.ly/1L0asP7',
#        'indices': [110, 132],
#        'url': 'http://t.co/AlY9U3Lyfo'}]},
#     'url': {'urls': [{'display_url': 'smrfoundation.org',
#        'expanded_url': 'http://www.smrfoundation.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/kJAVeFKzLe'}]}},
#    'favourites_count': 4187,
#    'follow_request_sent': False,
#    'followers_count': 4247,
#    'following': False,
#    'friends_count': 2354,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 87606674,
#    'id_str': '87606674',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 525,
#    'location': 'http://nodexl.codeplex.com/',
#    'name': 'Nodexl Project',
#    'notifications': False,
#    'profile_background_color': 'FFF04D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/87606674/1405285356',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/744708636/2010_-_March_-_NodeXL_-_Wiki_Graph_Cover_Image_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/744708636/2010_-_March_-_NodeXL_-_Wiki_Graph_Cover_Image_normal.png',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFF8AD',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nodexl',
#    'statuses_count': 3340,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'url': 'http://t.co/kJAVeFKzLe',
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:37:02 +0000 2016',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'rightrelevance.com/search/influen…',
#      'expanded_url': 'http://www.rightrelevance.com/search/influencers?query=data%20driven%20journalism&taccount=ddj_rr&time=1467729211.74',
#      'indices': [57, 80],
#      'url': 'https://t.co/pS5d79ir1i'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750337696753606656,
#   'id_str': '750337696753606656',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.rightrelevance.com" rel="nofollow">ddj_rr</a>',
#   'text': 'Top data driven journalism influencers one should follow https://t.co/pS5d79ir1i',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Dec 05 06:44:59 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Live content curated by top Data Driven Journalism #ddj Influencers. (Logo:https://t.co/ddaXijvo6c)',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1ZdenxW',
#        'expanded_url': 'http://bit.ly/1ZdenxW',
#        'indices': [75, 98],
#        'url': 'https://t.co/ddaXijvo6c'}]},
#     'url': {'urls': [{'display_url': 'bit.ly/12ESwZ8',
#        'expanded_url': 'http://bit.ly/12ESwZ8',
#        'indices': [0, 22],
#        'url': 'http://t.co/Xr6JR2pgYZ'}]}},
#    'favourites_count': 1,
#    'follow_request_sent': False,
#    'followers_count': 6080,
#    'following': False,
#    'friends_count': 4417,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2919294036,
#    'id_str': '2919294036',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 305,
#    'location': '',
#    'name': 'DataDrivenJournalism',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/738028619499343873/pAcANeMt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738028619499343873/pAcANeMt_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ddj_rr',
#    'statuses_count': 3482,
#    'time_zone': None,
#    'url': 'http://t.co/Xr6JR2pgYZ',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:35:27 +0000 2016',
#   'entities': {'hashtags': [{'indices': [121, 125], 'text': 'ddj'}],
#    'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#      'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#      'id': 750256075224584192,
#      'id_str': '750256075224584192',
#      'indices': [126, 144],
#      'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 262, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 750256661554683912,
#      'source_status_id_str': '750256661554683912',
#      'source_user_id': 130596773,
#      'source_user_id_str': '130596773',
#      'type': 'photo',
#      'url': 'https://t.co/PkdjHLEzVj'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#      'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#      'indices': [97, 120],
#      'url': 'https://t.co/ItaZ0ujn9O'}],
#    'user_mentions': [{'id': 130596773,
#      'id_str': '130596773',
#      'indices': [3, 8],
#      'name': 'GIJN',
#      'screen_name': 'gijn'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750337300001804290,
#   'id_str': '750337300001804290',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 05 14:30:36 +0000 2016',
#    'entities': {'hashtags': [{'indices': [111, 115], 'text': 'ddj'}],
#     'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#       'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#       'id': 750256075224584192,
#       'id_str': '750256075224584192',
#       'indices': [116, 139],
#       'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 262, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 750256661554683912,
#       'source_status_id_str': '750256661554683912',
#       'source_user_id': 130596773,
#       'source_user_id_str': '130596773',
#       'type': 'photo',
#       'url': 'https://t.co/PkdjHLEzVj'}],
#     'symbols': [],
#     'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#       'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#       'indices': [87, 110],
#       'url': 'https://t.co/ItaZ0ujn9O'}],
#     'user_mentions': []},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 750336080289947648,
#    'id_str': '750336080289947648',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/PkdjHLEzVj',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 07 19:22:52 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Global Investigative Journalism Network is an association of 138 nonprofit organizations in 62 countries dedicated to investigative reporting. Sp: @gijnEs',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gijn.org',
#         'expanded_url': 'http://www.gijn.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/xcMCJ1PqkB'}]}},
#     'favourites_count': 4970,
#     'follow_request_sent': False,
#     'followers_count': 13531,
#     'following': False,
#     'friends_count': 3268,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 130596773,
#     'id_str': '130596773',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 881,
#     'location': '',
#     'name': 'GIJN',
#     'notifications': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/130596773/1459422203',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_link_color': 'B30000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'gijn',
#     'statuses_count': 8974,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': 'http://t.co/xcMCJ1PqkB',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Sep 09 10:33:08 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Assistant Professor of Journalism Department/ The Faculty of Communication Arts/ Chulalongkorn University',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wefollow.com/cybercoffs',
#        'expanded_url': 'http://wefollow.com/cybercoffs',
#        'indices': [0, 23],
#        'url': 'https://t.co/qYEgGqCxYr'}]}},
#    'favourites_count': 114,
#    'follow_request_sent': False,
#    'followers_count': 1643,
#    'following': False,
#    'friends_count': 2091,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 16200361,
#    'id_str': '16200361',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 51,
#    'location': 'Bangkok Thailand',
#    'name': 'Narong Khamwijit',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/155404389/38651_1435922857204_1206954794_31248440_7277398_n.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/155404389/38651_1435922857204_1206954794_31248440_7277398_n.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16200361/1465899157',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/697595346424197120/ua4eWo5D_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/697595346424197120/ua4eWo5D_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'cybercoffs',
#    'statuses_count': 3441,
#    'time_zone': 'Bangkok',
#    'url': 'https://t.co/qYEgGqCxYr',
#    'utc_offset': 25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:33:37 +0000 2016',
#   'entities': {'hashtags': [{'indices': [121, 125], 'text': 'ddj'}],
#    'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#      'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#      'id': 750256075224584192,
#      'id_str': '750256075224584192',
#      'indices': [126, 144],
#      'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 262, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 750256661554683912,
#      'source_status_id_str': '750256661554683912',
#      'source_user_id': 130596773,
#      'source_user_id_str': '130596773',
#      'type': 'photo',
#      'url': 'https://t.co/PkdjHLEzVj'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#      'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#      'indices': [97, 120],
#      'url': 'https://t.co/ItaZ0ujn9O'}],
#    'user_mentions': [{'id': 130596773,
#      'id_str': '130596773',
#      'indices': [3, 8],
#      'name': 'GIJN',
#      'screen_name': 'gijn'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750336838041161728,
#   'id_str': '750336838041161728',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 05 14:30:36 +0000 2016',
#    'entities': {'hashtags': [{'indices': [111, 115], 'text': 'ddj'}],
#     'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#       'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#       'id': 750256075224584192,
#       'id_str': '750256075224584192',
#       'indices': [116, 139],
#       'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 262, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 750256661554683912,
#       'source_status_id_str': '750256661554683912',
#       'source_user_id': 130596773,
#       'source_user_id_str': '130596773',
#       'type': 'photo',
#       'url': 'https://t.co/PkdjHLEzVj'}],
#     'symbols': [],
#     'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#       'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#       'indices': [87, 110],
#       'url': 'https://t.co/ItaZ0ujn9O'}],
#     'user_mentions': []},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 750336080289947648,
#    'id_str': '750336080289947648',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/PkdjHLEzVj',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 07 19:22:52 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Global Investigative Journalism Network is an association of 138 nonprofit organizations in 62 countries dedicated to investigative reporting. Sp: @gijnEs',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gijn.org',
#         'expanded_url': 'http://www.gijn.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/xcMCJ1PqkB'}]}},
#     'favourites_count': 4970,
#     'follow_request_sent': False,
#     'followers_count': 13531,
#     'following': False,
#     'friends_count': 3268,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 130596773,
#     'id_str': '130596773',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 881,
#     'location': '',
#     'name': 'GIJN',
#     'notifications': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/130596773/1459422203',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_link_color': 'B30000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'gijn',
#     'statuses_count': 8974,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': 'http://t.co/xcMCJ1PqkB',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#   'text': 'RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 10 02:32:17 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Won't trade humanity for patriotism.",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'monstro.tv',
#        'expanded_url': 'http://monstro.tv',
#        'indices': [0, 23],
#        'url': 'https://t.co/gfobXXxy7V'}]}},
#    'favourites_count': 22854,
#    'follow_request_sent': False,
#    'followers_count': 617,
#    'following': False,
#    'friends_count': 385,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 20486857,
#    'id_str': '20486857',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 99,
#    'location': 'San Diego, CA',
#    'name': 'Dalton G Crosthwait',
#    'notifications': False,
#    'profile_background_color': '709397',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20486857/1467076908',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747600172721463296/8nFQF4-p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/747600172721463296/8nFQF4-p_normal.jpg',
#    'profile_link_color': 'E47458',
#    'profile_sidebar_border_color': '86A4A6',
#    'profile_sidebar_fill_color': 'A7CBCD',
#    'profile_text_color': '575757',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'dcrosthwait',
#    'statuses_count': 11001,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'url': 'https://t.co/gfobXXxy7V',
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 14:30:51 +0000 2016',
#   'entities': {'hashtags': [{'indices': [121, 125], 'text': 'ddj'}],
#    'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#      'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#      'id': 750256075224584192,
#      'id_str': '750256075224584192',
#      'indices': [126, 144],
#      'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#      'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 262, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 750256661554683912,
#      'source_status_id_str': '750256661554683912',
#      'source_user_id': 130596773,
#      'source_user_id_str': '130596773',
#      'type': 'photo',
#      'url': 'https://t.co/PkdjHLEzVj'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#      'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#      'indices': [97, 120],
#      'url': 'https://t.co/ItaZ0ujn9O'}],
#    'user_mentions': [{'id': 130596773,
#      'id_str': '130596773',
#      'indices': [3, 8],
#      'name': 'GIJN',
#      'screen_name': 'gijn'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750336141056839680,
#   'id_str': '750336141056839680',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 05 14:30:36 +0000 2016',
#    'entities': {'hashtags': [{'indices': [111, 115], 'text': 'ddj'}],
#     'media': [{'display_url': 'pic.twitter.com/PkdjHLEzVj',
#       'expanded_url': 'http://twitter.com/gijn/status/750256661554683912/photo/1',
#       'id': 750256075224584192,
#       'id_str': '750256075224584192',
#       'indices': [116, 139],
#       'media_url': 'http://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Cmlx7OZXEAAwReT.jpg',
#       'sizes': {'large': {'h': 788, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 462, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 262, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 750256661554683912,
#       'source_status_id_str': '750256661554683912',
#       'source_user_id': 130596773,
#       'source_user_id_str': '130596773',
#       'type': 'photo',
#       'url': 'https://t.co/PkdjHLEzVj'}],
#     'symbols': [],
#     'urls': [{'display_url': 'gijn.org/2016/07/05/top…',
#       'expanded_url': 'http://gijn.org/2016/07/05/top-ten-ddj-the-weeks-most-popular-data-journalism-links-102/',
#       'indices': [87, 110],
#       'url': 'https://t.co/ItaZ0ujn9O'}],
#     'user_mentions': []},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 750336080289947648,
#    'id_str': '750336080289947648',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/PkdjHLEzVj',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 07 19:22:52 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Global Investigative Journalism Network is an association of 138 nonprofit organizations in 62 countries dedicated to investigative reporting. Sp: @gijnEs',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gijn.org',
#         'expanded_url': 'http://www.gijn.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/xcMCJ1PqkB'}]}},
#     'favourites_count': 4970,
#     'follow_request_sent': False,
#     'followers_count': 13531,
#     'following': False,
#     'friends_count': 3268,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 130596773,
#     'id_str': '130596773',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 881,
#     'location': '',
#     'name': 'GIJN',
#     'notifications': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/130596773/1459422203',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/431819251817529346/xuOchsAc_normal.jpeg',
#     'profile_link_color': 'B30000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'gijn',
#     'statuses_count': 8974,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': 'http://t.co/xcMCJ1PqkB',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 01 12:20:18 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#Mass_Communication #PR #Commercial #Media       #マスコミ\u3000＃CM\u3000＃メディア\nЖич: Байгууллага төлөөлж бус, хувь хүнийхээ байр сууриас хандаж байгаа болно.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 699,
#    'follow_request_sent': False,
#    'followers_count': 3184,
#    'following': False,
#    'friends_count': 2003,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 128539032,
#    'id_str': '128539032',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 6,
#    'location': '',
#    'name': 'Tamiraa',
#    'notifications': False,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/115381611/godfather_l.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/115381611/godfather_l.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128539032/1394980360',
# ...
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 47,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jul 04 16:33:18 +0000 2016',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/XzdtdsG1yw',
#       'expanded_url': 'http://twitter.com/losotrosjudios/status/750004570110169088/photo/1',
#       'id': 750004315087974400,
#       'id_str': '750004315087974400',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/CmiM82zUMAATkpy.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CmiM82zUMAATkpy.jpg',
#       'sizes': {'large': {'h': 372, 'resize': 'fit', 'w': 462},
#        'medium': {'h': 372, 'resize': 'fit', 'w': 462},
#        'small': {'h': 372, 'resize': 'fit', 'w': 462},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/XzdtdsG1yw'}],
#     'symbols': [],
#     'urls': [{'display_url': 'theguardian.com/news/datablog/…',
#       'expanded_url': 'https://www.theguardian.com/news/datablog/2010/oct/23/wikileaks-iraq-data-journalism',
#       'indices': [88, 111],
#       'url': 'https://t.co/u0IMTZVjhu'}],
#     'user_mentions': []},
#    'favorite_count': 11,
#    'favorited': False,
#    'geo': None,
#    'id': 750004570110169088,
#    'id_str': '750004570110169088',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 47,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Mapa de los coches bomba que han explotado en Bagdad desde 2003. Feliz 4 de julio, USA! https://t.co/u0IMTZVjhu https://t.co/XzdtdsG1yw',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 30 15:48:45 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '¡No en nuestro nombre! Porque los Derechos Humanos están por encima de los lazos de sangre, religiosos, étnicos, etc. De la Patria Grande.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'losotrosjudios.com',
#         'expanded_url': 'http://losotrosjudios.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/qGBQwP1607'}]}},
#     'favourites_count': 1975,
#     'follow_request_sent': False,
#     'followers_count': 6712,
#     'following': False,
#     'friends_count': 1962,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1134434172,
#     'id_str': '1134434172',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 143,
#     'location': '',
#     'name': 'Los Otros Judíos',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/779662292/339e75220eceef50335d67cbc6c51864.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/779662292/339e75220eceef50335d67cbc6c51864.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1134434172/1419698516',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/725423036837560320/EKSPxoD0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/725423036837560320/EKSPxoD0_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'losotrosjudios',
#     'statuses_count': 30088,
#     'time_zone': 'Atlantic Time (Canada)',
#     'url': 'http://t.co/qGBQwP1607',
#     'utc_offset': -10800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @losotrosjudios: Mapa de los coches bomba que han explotado en Bagdad desde 2003. Feliz 4 de julio, USA! https://t.co/u0IMTZVjhu https:/…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 22 19:08:56 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '...y ahora que hacemos? ...continuar venciendo!  ...el era un filosofo que dominaba el tiempo emergente del que hablo Ortega y Gasset',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 156,
#    'follow_request_sent': False,
#    'followers_count': 793,
#    'following': False,
#    'friends_count': 1824,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2356788104,
#    'id_str': '2356788104',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 3,
#    'location': 'Venezuela',
#    'name': 'CHURUGUARA 68',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/438138146862034944/Pn8r5jWn_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/438138146862034944/Pn8r5jWn_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CHURUGUARA68',
#    'statuses_count': 9826,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 13:35:14 +0000 2016',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/29aXH73',
#      'expanded_url': 'http://bit.ly/29aXH73',
#      'indices': [89, 112],
#      'url': 'https://t.co/3txc9uiLKr'}],
#    'user_mentions': [{'id': 1336968696,
#      'id_str': '1336968696',
#      'indices': [3, 17],
#      'name': 'Kelvin Childs',
#      'screen_name': 'kelvin_childs'},
#     {'id': 17781955,
#      'id_str': '17781955',
#      'indices': [117, 124],
#      'name': 'Indeed',
#      'screen_name': 'indeed'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 750322144614187009,
#   'id_str': '750322144614187009',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 05 12:23:04 +0000 2016',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/29aXH73',
#       'expanded_url': 'http://bit.ly/29aXH73',
#       'indices': [70, 93],
#       'url': 'https://t.co/3txc9uiLKr'}],
#     'user_mentions': [{'id': 17781955,
#       'id_str': '17781955',
#       'indices': [98, 105],
#       'name': 'Indeed',
#       'screen_name': 'indeed'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 750303982531207168,
#    'id_str': '750303982531207168',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Journalism grads are leaving the field. What they want to do instead: https://t.co/3txc9uiLKr via @indeed',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 08 15:55:14 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Journalist. Raconteur. Artist. Actor.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 309,
#     'following': False,
#     'friends_count': 556,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1336968696,
#     'id_str': '1336968696',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': '',
#     'name': 'Kelvin Childs',
#     'notifications': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/570821181268172800/MYf4B2Jn_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570821181268172800/MYf4B2Jn_normal.jpeg',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'kelvin_childs',
#     'statuses_count': 1154,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @kelvin_childs: Journalism grads are leaving the field. What they want to do instead: https://t.co/3txc9uiLKr via @indeed',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Apr 22 23:34:31 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#journalism is my profession @starsandstripes  @NABJ member #FantasyFootballGuru #BulldogBasketball #podcastaljackal #foodie #wirehead #ogmmj',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'stripes.com',
#        'expanded_url': 'http://www.stripes.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/dDDOJ5iNc8'}]}},
#    'favourites_count': 1775,
#    'follow_request_sent': False,
#    'followers_count': 2005,
#    'following': False,
#    'friends_count': 617,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 34444009,
#    'id_str': '34444009',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 32,
#    'location': 'Washington,  DC',
#    'name': 'Ken-Yon Hardy',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/337982276/ScottCapturesStatetitle1.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/337982276/ScottCapturesStatetitle1.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34444009/1456030366',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/735811844322021376/lKlwbh5v_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735811844322021376/lKlwbh5v_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'KenYonHardy',
#    'statuses_count': 8605,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'url': 'https://t.co/dDDOJ5iNc8',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 05 13:31:15 +0000 2016',
#   'entities': {'hashtags': [{'indices': [27, 38], 'text': 'journalism'},
#     {'indices': [58, 66], 'text': 'BigData'},
#     {'indices': [70, 79], 'text': 'opendata'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ec.europa.eu/digital-single…',
#      'expanded_url': 'https://ec.europa.eu/digital-single-market/en/news/call-proposals-field-data-driven-news-production',
#      'indices': [116, 139],
#      'url': 'https://t.co/2g8GtNDPUj'}],
#    'user_mentions': [{'id': 205315827,
#      'id_str': '205315827',
#      'indices': [93, 99],
#      'name': 'DigitalSingleMarket',
#      'screen_name': 'DSMeu'},
#     {'id': 42586014,
#      'id_str': '42586014',
#      'indices': [100, 109],
#      'name': 'VoxEurop',
#      'screen_name': 'VoxEurop'},
#     {'id': 16143105,
#      'id_str': '16143105',
#      'indices': [110, 115],
#      'name': 'Open Knowledge Intl',
#      'screen_name': 'OKFN'}]},
#   'favorite_count': 3,
#   'favorited': False,
#   'geo': None,
#   'id': 750321141412134912,
#   'id_str': '750321141412134912',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'EU funding opportunity for #journalism appears to confuse #BigData w/ #opendata, or does it? @DSMeu @voxeurop @OKFN https://t.co/2g8GtNDPUj',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 19 15:46:24 +0000 2010',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Journalism sceptic working on the fringes of journalism. Writer of technical prose.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'karstens.eu',
#        'expanded_url': 'http://karstens.eu',
#        'indices': [0, 22],
#        'url': 'http://t.co/tYm4FhvIa9'}]}},
#    'favourites_count': 95,
#    'follow_request_sent': False,
#    'followers_count': 206,
#    'following': False,
#    'friends_count': 92,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 124495757,
#    'id_str': '124495757',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 28,
#    'location': '',
#    'name': 'Eric Karstens',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/124495757/1399362558',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/768027495/FuBK-Testbild_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/768027495/FuBK-Testbild_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'EricKarstens',
#    'statuses_count': 1160,
#    'time_zone': 'Bern',
#    'url': 'http://t.co/tYm4FhvIa9',
#    'utc_offset': 7200,
#    'verified': False}}]

# %%
first = response['statuses'][0]

# %%
first['user']['screen_name']
# Out:
# 'SocialBeeHQ'

# %%
first['text']
# Out:
# 'Data Journalism: A Simple Guide for Marketers via @HubSpot https://t.co/3vGbN7h3t4'

# %%
for item in response['statuses']:
    print(item['user']['screen_name'], "-", item['text'])
# Out:
# SocialBeeHQ - Data Journalism: A Simple Guide for Marketers via @HubSpot https://t.co/3vGbN7h3t4
# newsnerdnews - Six ways to generate data journalism stories https://t.co/62GBDcIhrW #ddj #
# RuudHouweling - Een kaart met daarop locaties van alle ontplofte autobommen in Bagdad. #zucht
#
# https://t.co/jMCKL4u4As https://t.co/HtZjaSUleS
# EuroScientist - RT @IE_AnneClaire: Data Journalism Awards celebrate evidence-based questioning in our society https://t.co/jToiOpgKxq @euroscientist https:…
# nodexl - Top Ten #ddj: The Week’s Most Popular Data Journalism Links https://t.co/FuMYXglSWb
# ddj_rr - Top data driven journalism influencers one should follow https://t.co/pS5d79ir1i
# cybercoffs - RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…
# dcrosthwait - RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…
# tamiraa_ts - RT @gijn: Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/Pkdj…
# gijn - Data-driven journalism Top 10: Brexit, Aleph data search tool, spacial data &amp; more https://t.co/ItaZ0ujn9O #ddj https://t.co/PkdjHLEzVj
# dumitruciorici - RT @dStanca: If you are a content producer/publisher, that's a must-see keynote (in my opinion). Full presentation, here (no... https://t.c…
# SnowdenEbooks - First time I've seen in a long history of data journalism just went live, and it's about corruption.
# ngmuntu - RT @ddj_rr: Dinosaur-killing asteroid may have caused global algal bloom, marine extinction - GeoSpace https://t.co/jCAccwvuHG https://t.co…
# CBCCorporate - CBC station @WRAL using multi-media investigative reporters and data based journalism on web and TV. https://t.co/je65Ke0d8H
# jdaviescoates - RT @cijournalism: Exciting opportunity @TBIJ - Director for new Local Data Lab, building data-driven resources for local journalists https:…
# emilydabau - RT @knightfdn: .@univmiami conference to explore intersection of #datajournalism and digital humanities https://t.co/IWhDM9szOS #ddj #data
# bertiebee - Is the quest for views having an impact on journalistic quality? https://t.co/l5aZH5kt4o https://t.co/CWSY41e6um
# CHURUGUARA68 - RT @losotrosjudios: Mapa de los coches bomba que han explotado en Bagdad desde 2003. Feliz 4 de julio, USA! https://t.co/u0IMTZVjhu https:/…
# KenYonHardy - RT @kelvin_childs: Journalism grads are leaving the field. What they want to do instead: https://t.co/3txc9uiLKr via @indeed
# EricKarstens - EU funding opportunity for #journalism appears to confuse #BigData w/ #opendata, or does it? @DSMeu @voxeurop @OKFN https://t.co/2g8GtNDPUj

# %%
response = twitter.search(q="data journalism :)",
                   result_type="recent",
                   geocode="40.807474, -73.963256,100mi",
                 count=100)

# %%
len(response['statuses'])
# Out:
# 0

# %%
for item in response['statuses']:
    print("https://twitter.com/" + item['user']['screen_name'])

# %%
response = twitter.get_user_timeline(screen_name="columbiajourn", count = 50, include_rts=False, exclude_replies=True)

# %%
for item in response:
    print(item['text']) # less than 50 because it is excluding retweets and replies after it retrieves the 50
# Out:
# If you're covering @Rio2016_en, here are some insights on Brazil: https://t.co/siKlDByz0c
# RIP, @MsToniRandolph. https://t.co/Sk2ZOvW5VT
# Final hour of giving for the Annual Fund: https://t.co/txFzXZ7rHI
# You're on deadline for the Annual Fund, 14 hours (EST) remain: https://t.co/txFzXZ7rHI https://t.co/PVbCl5ve9E
# It's not too late to contribute to the future of journalism through the Annual Fund. https://t.co/txFzXZ7rHI https://t.co/YsHB34WQpz
# #cjs59 Paul Zimmerman, aka "Dr. Z," writes about his Jschool experience in this memoir excerpt: https://t.co/d1PT4m0f36 @SInow
# For #WVAfloods coverage, see @NBCNews #cjs12 @MorganRadford https://t.co/nKEtr8KsXn
# Congrats to @MagnumPhotos Nominee &amp; #cjs10 @dianamarkosian. Her work explores her Armenian heritage &amp; memory https://t.co/Rug8kUh0TC
# 2/2 #canalampliado included grad contributors
# Matteo Lonardi, @aglorios, @SarahLJorgensen &amp; @simko_bednarski
# https://t.co/uVXWsQ3z28
# 1/2 Adj Prof Walt Bogdanich, #cjs15 @jacwil28 &amp; @agMendezPty co-authored @nytimes article on #canalampliado
#  https://t.co/uVXWsQ3z28
# From Prof @gianninasegnini &amp;  students: investigation on the side you don't see of the cruise industry @UniNoticias https://t.co/jnmvseYQPK

# %%
response = twitter.get_user_timeline(screen_name="horse_ebooks", count = 100, include_rts=False, exclude_replies=True)

# %%
for item in response:
    print(item['text'])
# Out:
# Bear Stearns Bravo
# (213) 444 0102
# http://t.co/fFjVzCrTrZ
# I m going to outline 14 different ways that I ve found you
# The real goal of any talk or speech
# All Star Personal Trainers http://t.co/5dcCqnMvVG
# to discourage you by telling
# space in your house How to sell faster than your neighbors How to make a strategic use
# -And Gain Power By Learning Ways To Become Peaceful
# This is a very special technique that I have never seen
# Turn Eye Appeal Into Buy Appeal http://t.co/F6hrzPvxdG
# One of the greatest barriers to making the sale is your prospect s natural
# Don t stubbornly
# process from preparation, through to delivery.
# principle to work to make more money while having more fun. Unlucky people
# Learn to Trade Markets http://t.co/oQfel4MvC0
# And practical explanations
# Then I decided to try an experiment and put all of my hard work to the test. The next morning I got up and walked straight to my computer..
# In less than three weeks you can be looking at things differently, more creatively, if you
# Why many people achieve very little despite spending most of their time
# Conversational Japanese Video Course http://t.co/pFpT5DMKf0
# How many times have you wished you were strong enough to concentrate your mind,
# displayed are all for right-handers? I ll show
# your daily life, and also in difficult and trying situations.
# face year
# One Hundred and One Patchwork Patterns http://t.co/29fXVfYG2W
# The interviews can be shorter since you would have many
# We both have discussed, researched heavily
# of the court again once you ve
# The &amp;quot;Battle Tested&amp;quot; Technique The &amp;quot;Swap Me&amp;quot; Technique The &amp;quot;Prize
# Miracle Mind Manifesting Program http://t.co/j7nlDXPmJA
# I have personally used this technique to break many memory
# AND BURNED BY UNSCRUPULOUS BUSINESSES MORE TIMES
# breath, and vice versa. How many of the common things I and others thought we were doing
# and how often they hear it.
# Essays for Undergraduate Programs http://t.co/ZBoTONj6pW
# No circus act lifts or beach body workouts.
# Overheads are low, usually just
# Discussion
# another place would tell
# Do these simple things, and you are guaranteed to keep your license (or regret it
# Getting Started In Auto Sales http://t.co/EhQQcWVpeX
# But that s just basic
# This sounds like the beginning of a brutal experience, that I personally
# and more SECURE FUTURE
# and more! Start raising your self-esteem today!
# Saving On Cleaning Supplies http://t.co/lDpswspwND
# term effects Packaging
# All the various circumstances you might encounter when turning
# New cars, clothes,
# wild don t diet, and neither should you.
# Discover new tactics to solve your computer problems http://t.co/uYsv65V704
# and that geological significance should not be lost in the search for more and more
# Life style strategies to support your youthful memory.
# &amp;amp; visual perception, Memory,
# attention to more and more comforts to make your
# Essenial Guide to Lasting Pain Relief http://t.co/V9f3mrahuL
# remember and fun to share.
# Novice and seasoned tomato growers alike find this section invaluable, as it contains everything you
# Even The Best Won t
# Culture Revealed.
# And for many, it does both.
# Vertical Jump Training Program http://t.co/FAuzhDHKAq
# I am not sure of his feelings and I would
# What value could
# .RAVEL. .RAVEL. .RAVEL. .RAVEL. .RAVEL. .RAVEL. .RAVEL. .RAVEL. GRADING AND GRAVEL. .RADING AND GRAVEL. GRAVEL. GRADING AND GRAVEL. TOTAL
# What if you could do the very
# Decorate With Wallpaper http://t.co/lWdeBR1lkX
# are worth the attention to create a "balance".
# of events get you the
# In 2004, two independent dental research teams completed
# Not only that, but whether you believe it (or want to believe it) the car salesmen will continue to laugh
# Jet Lag Plane http://t.co/WKo6dEi6rR
# Including simplified four part arrangements for the novice student and
# Demand Furniture
# Just look at everything that I am going
# shopping format allows you to identify and measure quality of products and services. The need to
# 101 Money Saving Cost Cutting Tips http://t.co/iqI3mW0koA
# countertops to make certain
# your roses. Realize that rain water
# Why you should think twice about painting the walls in your house anything
# at the insights you gain about those weird, bizarre symbols in your dreams.
# Lawn Mower Style Line Trimmer http://t.co/B8k2s4QEvd
# to make any sales Haven t a Clue of What Makes it Happen Have problems with creativity. Have not started marketing on the net Don t have
# You ll receive an over
# INTRODUCTORY.--HOW WE MET. I. INTRODUCTORY.--HOW WE MET II. HOW TO TALK III. TALK IV. HOW
# She knows I m a no-nonsense medical researcher who has dedicated my life to finding all-natural treatments for devastating
# How to Have Healthy Hair - At Any Age http://t.co/gBFR3pzQLR
# Would the person who would have to step-in know
# influential ways
# Enjoy hours-long
# I ve created this important 15-page report to reveal the best option to preserve your wealth, secure
# Love Secrets http://t.co/Vmyejvyjut
# (This section can actually give you a whole new way to communicate with
# at the proper time within the recuperative cycle.
# When done, lightly
# Are 3000 Mile Oil Changes
# How to Buy Owner Financed Homes http://t.co/UlnqbKeJut
# Crumbs
# I d say at one point in our lives everyone

# %% [markdown]
# ## cursor

# %%
cursor = twitter.cursor(twitter.search, q='"data journalism", -filter:retweets', count = 100)

# %%
all_text = list()
for tweet in cursor:
    all_text.append(tweet['text'])
    if len(all_text) > 500:
        break
