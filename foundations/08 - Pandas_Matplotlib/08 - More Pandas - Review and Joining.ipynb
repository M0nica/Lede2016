# %% [markdown]
# # The setup
#
# A lot of times when you're using pandas you're also going to use matplotlib, and when you're using matplotlib you're also going to be making inline graphics. So why not do it all at once?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/Monica/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))

# %% [markdown]
# # The import
#
# Always name your initial dataframe `df`. Always always always. Why? Because everyone else does, and because
#
# * when you slice it and dice it into different pieces (only really rich people, only cats, only flights to Finland, etc)
# * you can give each of those names, while knowing `df` is your original dataframe.

# %%
df = pd.read_excel("rich_people.xlsx")

# %% [markdown]
# # The examining
#
# Your best friends for a quick peek are are
#
# * `df.head()` to see the first ten
# * `df.columns` to see the column names
# * `df.info()` to see more detailed info about each column
# * `df.describe()` to see summary statistics about each numeric column
#
# Once you do these few steps, you should be able to draw up a list of ten or so questions to ask your data.

# %%
df.head()
# Out:
#    year                         name  rank           citizenship countrycode  \
# 0  2001          A Jerrold Perenchio   151         United States         USA
# 1  2014         A. Jerrold Perenchio   663         United States         USA
# 2  2001  Abdul Al Rahman  Al Jeraisy   336          Saudi Arabia         SAU
# 3  2001        Abdul Aziz Al Ghurair   251  United Arab Emirates         ARE
# 4  1996       Abdul Aziz Al-Sulaiman   404          Saudi Arabia         SAU
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 0                3.0  self-made            executive   male  70.0   ...
# 1                2.6  self-made            executive   male  83.0   ...
# 2                1.5  self-made  founder non-finance   male   NaN   ...
# 3                1.9  inherited            inherited   male  47.0   ...
# 4                1.0  self-made    self-made finance   male   0.0   ...
#
#      relationshiptocompany foundingdate  gdpcurrentus         sourceofwealth  \
# 0  former chairman and CEO       1955.0  1.062180e+13                    NaN
# 1  former chairman and CEO       1955.0           NaN  television, Univision
# 2                  founder       1956.0  1.830120e+11                    NaN
# 3                 relation       1960.0  1.030000e+11                    NaN
# 4                  founder       1968.0  1.577430e+11                    NaN
#
#                                             notes  notes2  \
# 0  represented Marlon Brando and Elizabeth Taylor     NaN
# 1  represented Marlon Brando and Elizabeth Taylor     NaN
# 2                                             NaN     NaN
# 3                           inherited from father     NaN
# 4                                             NaN     NaN
#
#                                               source  \
# 0       http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1       http://en.wikipedia.org/wiki/Jerry_Perenchio
# 2  http://www.jeraisy.com.sa/index.php/pages/rend...
# 3                                                NaN
# 4  http://www.arabianbusiness.com/arabian-busines...
#
#                                             source_2  \
# 0  http://www.forbes.com/profile/a-jerrold-perenc...
# 1  http://www.forbes.com/profile/a-jerrold-perenc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             source_3 source_4
# 0  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 30 columns):
# year                       2614 non-null int64
# name                       2614 non-null object
# rank                       2614 non-null int64
# citizenship                2614 non-null object
# countrycode                2614 non-null object
# networthusbillion          2614 non-null float64
# selfmade                   2592 non-null object
# typeofwealth               2592 non-null object
# gender                     2580 non-null object
# age                        2429 non-null float64
# industry                   2613 non-null object
# IndustryAggregates         2613 non-null object
# region                     2614 non-null object
# north                      2614 non-null int64
# politicalconnection        78 non-null float64
# founder                    2614 non-null int64
# generationofinheritance    2614 non-null object
# sector                     2591 non-null object
# company                    2576 non-null object
# companytype                2578 non-null object
# relationshiptocompany      2568 non-null object
# foundingdate               2574 non-null float64
# gdpcurrentus               949 non-null float64
# sourceofwealth             1639 non-null object
# notes                      1190 non-null object
# notes2                     197 non-null object
# source                     2571 non-null object
# source_2                   2143 non-null object
# source_3                   775 non-null object
# source_4                   23 non-null object
# dtypes: float64(5), int64(4), object(21)
# memory usage: 612.7+ KB

# %%
df.describe()
# Out:
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               year         rank  networthusbillion          age        north  \
# count  2614.000000  2614.000000        2614.000000  2429.000000  2614.000000
# mean   2008.411630   599.672533           3.531943    57.403870     0.640398
# std       7.483598   467.885695           5.088813    21.386215     0.479976
# min    1996.000000     1.000000           1.000000   -42.000000     0.000000
# 25%    2001.000000   215.000000           1.400000          NaN     0.000000
# 50%    2014.000000   430.000000           2.000000          NaN     1.000000
# 75%    2014.000000   988.000000           3.500000          NaN     1.000000
# max    2014.000000  1565.000000          76.000000    98.000000     1.000000
#
#        politicalconnection      founder  foundingdate  gdpcurrentus
# count                 78.0  2614.000000   2574.000000  9.490000e+02
# mean                   1.0     0.477429   1954.621989  4.879155e+12
# std                    0.0     0.499586     43.189003  4.428305e+12
# min                    1.0     0.000000   1610.000000  2.491801e+09
# 25%                    NaN     0.000000           NaN           NaN
# 50%                    NaN     0.000000           NaN           NaN
# 75%                    NaN     1.000000           NaN           NaN
# max                    1.0     1.000000   2012.000000  1.062180e+13

# %% [markdown]
# # Slicing your data
#
# I made a *terrible mistake* on Monday about how I taught sub-selects (the things that are basically SQL `WHERE` statements), and it's all because of how I named my variables.
#
# We're going to take a sample of the data to work with so it looks a little cleaner - only take a few columns of the first 8. It's a complicated line, don't sweat it. Just think about the result for now.

# %%
recent = df[df['year'] == 2014]
recent = recent[['name','age','gender','selfmade','industry','networthusbillion','countrycode','rank']]
recent = recent.head(8)

# %% [markdown]
# Who is from the USA? There **two different things we can do**. This was a big point of confusion in class
#
# 1. We can **list whether someone is from the USA or not.**
# 2. Or, we can use that list to **select only the people from the USA.**
#
# Let's look at them both, then see how they're used.

# %%
recent['countrycode'] == 'USA'
# Out:
# 1      True
# 5     False
# 6     False
# 8     False
# 9     False
# 12     True
# 15    False
# 17    False
# Name: countrycode, dtype: bool

# %%
americans = recent[recent['countrycode'] == 'USA']
americans
# Out:
#                     name   age  gender   selfmade          industry  \
# 1   A. Jerrold Perenchio  83.0    male  self-made             Media
# 12       Abigail Johnson  52.0  female  inherited  Money Management
#
#     networthusbillion countrycode  rank
# 1                 2.6         USA   663
# 12               17.3         USA    50

# %% [markdown]
# This just gave us a list of `True` and `False` values.
#
# * First person? Definitely from the USA.
# * Next row? Not from the USA.
# * Third person? Not from the USA.
# * Fourth? Yes, they're from the USA.
#
# On the other hand, we can also use similar syntax to get a list of every person from the USA.

# %%
recent['countrycode'].value_counts()
# Out:
# ARE    2
# USA    2
# SAU    1
# IDN    1
# BRA    1
# NGA    1
# Name: countrycode, dtype: int64

# %%
recent['countrycode'].value_counts().plot(kind="barh")

# %% [markdown]
# That one was a two-step process,
#
# 1. we got a list of `True`/`False` values (are they from the USA?), then
# 2. **fed that `True`/`False` list back into the dataframe.**
#
# For every row that's `True`, it let us keep the row. If it was `False`, it doesn't let us keep the row.
#
# ## When to use what
#
# Let's say we wanted to select every single row that is from USA, has inherited wealth, and is in the top 10 wealthiest people in the world. If we wanted to do it all on one line, we could!

# %%
recent.groupby('countrycode')['networthusbillion'].sum()
# Out:
# countrycode
# ARE     7.3
# BRA     2.8
# IDN     1.6
# NGA     1.2
# SAU     2.4
# USA    19.9
# Name: networthusbillion, dtype: float64

# %%
recent.groupby('countrycode')['networthusbillion'].sum().plot(kind="barh")

# %% [markdown]
# That looks *super confusing*. In it we have three separate things we're testing for (a.k.a. getting True/False back)
#
# * `sample['countrycode'] == 'USA'`
# * `sample['selfmade'] == 'inherited'`
# * `sample['rank'] < 10`
#
# And we're jamming them all into `sample[blah blah]` to get back a dataframe for which all of those are true. It works, but it's ugly.
#
# Again, let's remind ourselves what a piece like that looks like, it's **just a list of True and False values**

# %% [markdown]
# If we felt like the code we had before was a little too complicated, we could break it down into manageable, well-named pieces like this:

# %% [markdown]
# Let's look at each individual piece.
#
# `is_american`, which is the same thing as `sample['countrycode'] == 'USA'`, is **not** a list of people. It is **not** a dataframe. It is a **list of true and false values**.

# %% [markdown]
# It's the same thing with `is_inherited` and `is_top_ten`. It's just a shortcut for me, so I don't have to type out `sample['selfmade'] == 'inherited'`. We can combine them all using `&` to get a list of `True`/`False` values in which every one of those conditions is true

# %% [markdown]
# Which we can then feed into the dataframe

# %% [markdown]
# So what I'm saying is, these two things are the same:
#
# ### Method One: Breaking into separate readable things

# %% [markdown]
# ### Method Two: Doing it all at once

# %% [markdown]
# ### Make sure you know the difference between these two
#
# * `df['countrycode'] == 'USA'`
# * `df[df['countrycode'] == 'USA']`

# %% [markdown]
# # Joining data
#
# Now, let's say we wanted to join a bunch of data together. We have a lot of countries here, right? And we'd like to know how much of their wealth is concentrated in these rich people.

# %%
recent = df[df['year'] == 2014]
recent = recent[['name','countrycode','networthusbillion']]
recent.head()
# Out:
#                            name countrycode  networthusbillion
# 1          A. Jerrold Perenchio         USA                2.6
# 5            Abdulla Al Futtaim         ARE                2.5
# 6  Abdulla bin Ahmad Al Ghurair         ARE                4.8
# 8             Abdullah Al Rajhi         SAU                2.4
# 9              Abdulsamad Rabiu         NGA                1.2

# %% [markdown]
# ## What do we combine it with?
#
# I'm going to get my GDP data from [this web site](http://statisticstimes.com/economy/world-gdp-ranking.php), because... I googled GDP 2014 and it came up.
#
# We could manually say okay, so A. Jerrold Perenchio	has 2.6 billion dollars, and USA's GDP was 17.418 trillion (17418 billion), so he's at about 0.015% of the GDP. **But we are lazy, so we want the computer to do it.** In order to do that, though, we need to **merge that information into our existing dataset.**
#
# I'm also too lazy to look up the GDP for every country, so I'm just going to pick the top ten.

# %%
# Make a list of dictionaries
country_gdp = [
   { 'country': 'USA', 'gdp': 17.418 },
   { 'country': 'DEU', 'gdp': 3.859 },
   { 'country': 'CHN', 'gdp': 10.380 },
   { 'country': 'RUS', 'gdp': 1.857 },
   { 'country': 'JPN', 'gdp': 4.616 },
   { 'country': 'BRA', 'gdp': 2.353 },
   { 'country': 'HKG', 'gdp': 0.289 },
   { 'country': 'FRA', 'gdp': 2.846 },
   { 'country': 'GBR', 'gdp': 2.945 },
   { 'country': 'IND', 'gdp': 2.049 }
]

# %% [markdown]
# I'm also too lazy to find a csv that has the data I need, so **I'm going to make a dataframe out of a dictionary**. It's pretty easy.

# %%
gdp_df = pd.DataFrame(country_gdp)
gdp_df
# Out:
#   country     gdp
# 0     USA  17.418
# 1     DEU   3.859
# 2     CHN  10.380
# 3     RUS   1.857
# 4     JPN   4.616
# 5     BRA   2.353
# 6     HKG   0.289
# 7     FRA   2.846
# 8     GBR   2.945
# 9     IND   2.049

# %% [markdown]
# I could have read it in from a csv, but since I didn't have a csv I might as well just type it out. I also want it in *billions*, not in *trillions*, so let's add a column real quick

# %%
gdp_df['billions'] = gdp_df['gdp'] * 1000 #convert trillions to billions

# %%
gdp_df
# Out:
#   country     gdp  billions
# 0     USA  17.418   17418.0
# 1     DEU   3.859    3859.0
# 2     CHN  10.380   10380.0
# 3     RUS   1.857    1857.0
# 4     JPN   4.616    4616.0
# 5     BRA   2.353    2353.0
# 6     HKG   0.289     289.0
# 7     FRA   2.846    2846.0
# 8     GBR   2.945    2945.0
# 9     IND   2.049    2049.0

# %%
gdp_df.head(2)
# Out:
#   country     gdp  billions
# 0     USA  17.418   17418.0
# 1     DEU   3.859    3859.0

# %%
recent.head(2)
# Out:
#                    name countrycode  networthusbillion
# 1  A. Jerrold Perenchio         USA                2.6
# 5    Abdulla Al Futtaim         ARE                2.5

# %% [markdown]
# ### STEP ONE: Finding a join key
#
# My favorite resource for joining data with `pandas` is [this page](http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html#compare-with-sql-join). It compares everything to SQL JOINs, which *I* understand. You could also check out [this page](http://pandas.pydata.org/pandas-docs/stable/merging.html#database-style-dataframe-joining-merging) which I find kind of confusing.
#
# So what we need to do is **match up a column between our two dataframes.**

# %%
# we are matching up country code from recent
# to 
# country code from gdp_df

# %% [markdown]
# It looks like we're going to be matching up **`countrycode`** from `df` with **`country`** from `gdp_df`.
#
# ### STEP TWO: Doing the merge
#
# You merge using **`.merge`**, and then give two parameters:
#
# * **`left_on`**, the first dataframe's column name to merge on
# * **`right_on`**, the second dataframe's column name to merge on

# %%
merged = recent.merge(gdp_df, left_on='countrycode', right_on='country')
merged.head()
# Out:
#                        name countrycode  networthusbillion country     gdp  \
# 0      A. Jerrold Perenchio         USA                2.6     USA  17.418
# 1           Abigail Johnson         USA               17.3     USA  17.418
# 2  Aerin Lauder Zinterhofer         USA                1.1     USA  17.418
# 3                Alan Gerry         USA                1.4     USA  17.418
# 4                Alec Gores         USA                2.0     USA  17.418
#
#    billions
# 0   17418.0
# 1   17418.0
# 2   17418.0
# 3   17418.0
# 4   17418.0

# %%
len(gdp_df) # only have 10 GDP's -- had a lot more countries
# Out:
# 10

# %% [markdown]
# Hmmm see how rank skips through 1, 4, 5, 6, 6? This is because **we only kept rows we have matches for**. The second wealthiest person is from Mexico, but since we didn't have GDP from Mexico it left. You can see if we just do a simple `.count()`

# %%
recent['countrycode'].describe() # there are a lot of countries
# Out:
# count     1653
# unique      69
# top        USA
# freq       499
# Name: countrycode, dtype: object

# %%
merged[merged['countrycode'] == 'SAU'] # it's empty :(because we did not have a GDP for SAU when we merged, 
# therefore they were thrown out because we did not have a match
# Out:
# Empty DataFrame
# Columns: [name, countrycode, networthusbillion, country, gdp, billions]
# Index: []

# %%
recent[recent['countrycode'] == 'SAU'] # there were ppl before!
# Out:
#                                                name countrycode  \
# 8                                 Abdullah Al Rajhi         SAU
# 1711                             Mohammad Al Amoudi         SAU
# 1713                               Mohammed Al Issa         SAU
# 1902               Prince Alwaleed Bin Talal Alsaud         SAU
# 1903  Prince Sultan bin Mohammed bin Saud Al Kabeer         SAU
# 2125                                    Saleh Kamel         SAU
# 2292                              Sulaiman Al Rajhi         SAU
#
#       networthusbillion
# 8                   2.4
# 1711               15.3
# 1713                3.1
# 1902               20.4
# 1903                3.5
# 2125                2.4
# 2292                1.9

# %% [markdown]
# We lost like 500 people! Maybe even if we don't have the GDP of their country we want to keep them?
#
# ### Types of joins
#
# Let's just look at our data real quick before I explain the two major types of joins.

# %%
len(merged)
# Out:
# 1130

# %%
len(recent)
# Out:
# 1653

# %%
left_merged = recent.merge(gdp_df, how="left", left_on="countrycode", right_on="country")
left_merged.head() # always keep what is on the left -- allows you to have empty non-matching values
# Out:
#                            name countrycode  networthusbillion country  \
# 0          A. Jerrold Perenchio         USA                2.6     USA
# 1            Abdulla Al Futtaim         ARE                2.5     NaN
# 2  Abdulla bin Ahmad Al Ghurair         ARE                4.8     NaN
# 3             Abdullah Al Rajhi         SAU                2.4     NaN
# 4              Abdulsamad Rabiu         NGA                1.2     NaN
#
#       gdp  billions
# 0  17.418   17418.0
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %%
len(left_merged)
# Out:
# 1653

# %%
#This will tell you if something is NaN or not 
left_merged['billions'].isnull() # NaN is not a string!! 

only_people_with_gdps = left_merged[left_merged['billions'].notnull()]
only_people_with_gdps
# Out:
#                             name countrycode  networthusbillion country  \
# 0           A. Jerrold Perenchio         USA                2.6     USA
# 5                Abigail Johnson         USA               17.3     USA
# 6        Abilio dos Santos Diniz         BRA                2.8     BRA
# 8                     Adi Godrej         IND                3.5     IND
# 9       Aerin Lauder Zinterhofer         USA                1.1     USA
# 14     2.049    2049.0
# 15     2.049    2049.0
# 16     4.616    4616.0
# 17     4.616    4616.0
# 19     2.846    2846.0
# 20     2.846    2846.0
# 21     2.846    2846.0
# 22    17.418   17418.0
# 23     2.945    2945.0
# 27     1.857    1857.0
# 28     3.859    3859.0
# 29     0.289     289.0
# 35    17.418   17418.0
# 37     2.945    2945.0
# 38     1.857    1857.0
# 39     1.857    1857.0
# 40     1.857    1857.0
# 41    17.418   17418.0
# 43     1.857    1857.0
# 44     1.857    1857.0
# 45     1.857    1857.0
# 46     1.857    1857.0
# 47    17.418   17418.0
# 48     1.857    1857.0
# ...      ...       ...
# 1617   4.616    4616.0
# 1618   4.616    4616.0
# 1620  10.380   10380.0
# 1621   1.857    1857.0
# 1622   1.857    1857.0
# 1623   1.857    1857.0
# 1625   4.616    4616.0
# 1626   2.049    2049.0
# 1627   3.859    3859.0
# 1629   1.857    1857.0
# 1631   1.857    1857.0
# 1632  10.380   10380.0
# 1633  10.380   10380.0
# 1634  10.380   10380.0
# 1635  10.380   10380.0
# 1636  10.380   10380.0
# 1637  10.380   10380.0
# 1638  10.380   10380.0
# 1639  10.380   10380.0
# 1640   0.289     289.0
# 1641  10.380   10380.0
# 1643  10.380   10380.0
# 1644  10.380   10380.0
# 1645  10.380   10380.0
# 1646  10.380   10380.0
# 1647  10.380   10380.0
# 1648  10.380   10380.0
# 1649   1.857    1857.0
# 1650   1.857    1857.0
# 1651  10.380   10380.0
#
# [1130 rows x 6 columns]

# %% [markdown]
# ### Inner joins
#
# The default kind of join is an **inner** join. It requires you to have a match on the left hand side AND the right hand side.
#
# **If you're in the original dataframe and you don't have a match in the joining dataframe, you disappear.** Watch how Carlos "Slim" Helu and Amancio Ortega both disappear.

# %% [markdown]
# ### Left join
#
# The other major kind of join is a **left join**. The "left" dataframe (the one you type first), gets to keep its rows, even if there aren't any matches in the joining dataframe.

# %% [markdown]
# ### Other stuff
#
# Did you see this image already? Well, now you have.
#
# ![](http://i.imgur.com/7Ssc4l.jpg)

# %%
nba = pd.read_csv("NBA-Census-10.14.2013.csv", encoding="mac_roman")
nba.head()
# Out:
#                  Name  Age           Team POS   #       2013 $  Ht (In.)   WT  \
# 0         Gee, Alonzo   26      Cavaliers   F  33   $3,250,000        78  219
# 1     Wallace, Gerald   31        Celtics   F  45  $10,105,855        79  220
# 2        Williams, Mo   30  Trail Blazers   G  25   $2,652,000        73  195
# 3   Gladness, Mickell   27          Magic   C  40     $762,195        83  220
# 4  Jefferson, Richard   33           Jazz   F  44  $11,046,000        79  230
#
#    EXP  1st Year         DOB       School               City  \
# 0    4      2009   5/29/1987      Alabama  Riviera Beach, FL
# 1   12      2001   7/23/1982      Alabama      Sylacauga, AL
# 2   10      2003  12/19/1982      Alabama        Jackson, MS
# 3    2      2011   7/26/1986  Alabama A&M     Birmingham, AL
# 4   12      2001   6/21/1980      Arizona    Los Angeles, CA
#
#   State (Province, Territory, Etc..) Country   Race HS Only
# 0                            Florida      US  Black      No
# 1                            Alabama      US  Black      No
# 2                        Mississippi      US  Black      No
# 3                            Alabama      US  Black      No
# 4                         California      US  Black      No

# %%
nba.sort_values(by="Age", ascending=False).head(4)
# Out:
#               Name  Age     Team  POS   #      2013 $  Ht (In.)   WT  EXP  \
# 392    Nash, Steve   39   Lakers    G  10  $9,300,500        75  178    7
# 225  Camby, Marcus   39  Rockets  F/C  21    $884,293        83  240   17
# 23   Fisher, Derek   39  Thunder    G   6    $884,293        73  210   17
# 63      Allen, Ray   38     Heat    G  34  $3,229,050        77  205   17
#
#      1st Year        DOB                School              City  \
# 392      2006   2/7/1974           Santa Clara  Johannesburg, SA
# 225      1996  3/22/1974         Massachusetts      Hartford, CT
# 23       1996   8/9/1974  Arkansas-Little Rock   Little Rock, AR
# 63       1996  7/20/1975           Connecticut        Merced, CA
#
#     State (Province, Territory, Etc..)       Country   Race HS Only
# 392                                n/a  South Africa  White      No
# 225                        Connecticut            US  Black      No
# 23                            Arkansas            US  Black      No
# 63                          California            US  Black      No

# %%
nba.sort_values(by="2013 $") # this is not a number but a string
# Out:
#                          Name  Age           Team  POS   #      2013 $  \
# 44          Stephenson, Lance   23         Pacers    G   1  $1,005,000
# 132           Morrow, Anthony   28       Pelicans    G   3  $1,027,424
# 148                 White, DJ   27          Bulls    F   6  $1,027,424
# 93              Singler, Kyle   25        Pistons  G/F  25  $1,045,000
# 238            Morris, Darius   22          76ers    G   7  $1,046,269
# 319          Nedovi?, Nemanja   22       Warriors    G   8  $1,056,720
# 191           Goodwin, Archie   19           Suns    G  20  $1,064,400
# 483             Ezeli, Festus   23       Warriors    C  31  $1,066,920
# 186           Teague, Marquis   20          Bulls    G  25  $1,074,720
# 274              Gobert, Rudy   21           Jazz    C  27  $1,078,800
# 26               Jones, Perry   22        Thunder    F   3  $1,082,520
# 252          Moultrie, Arnett   22          76ers    F   5  $1,089,240
# 363           Graham, Stephen   31          Bucks  G/F  23  $1,106,941
# 384             Jones, Dwayne   30           Jazz  F/C  42  $1,106,942
# 408               Young, Nick   28         Lakers  G/F   0  $1,106,942
# 218             Butler, Jimmy   24          Bulls  G/F  21  $1,112,880
# 442              Joseph, Cory   22          Spurs    G   5  $1,120,920
# 87             Plumlee, Miles   25           Suns  F/C  22  $1,121,520
# 46               Cole, Norris   25           Heat    G  30  $1,129,200
# 387            Mills, Patrick   25          Spurs    G   8  $1,133,950
# 481             Price, Ronnie   30          Magic    G  10  $1,146,337
# 338           Bullock, Reggie   22       Clippers  G/F  25  $1,149,000
# 503              Wroten, Tony   20          76ers    G   8  $1,160,040
# 451          Hamilton, Jordan   23        Nuggets  G/F   1  $1,169,880
# 22             Brewer, Ronnie   28        Rockets  G/F  10  $1,186,459
# 241        Hardaway, Tim, Jr.   21         Knicks    G   5  $1,196,760
# 54           Thabeet, Hasheem   26        Thunder    C  34  $1,200,000
# 293               Anti?, Pero   31          Hawks  F/C   6  $1,200,000
# 369         Cunningham, Jared   22          Hawks    G   7  $1,208,400
# 376           Brooks, MarShon   24        Celtics  G/F  12  $1,210,080
# ..                        ...  ...            ...  ...  ..         ...
# 251  Becton-Buckner, Reginald   22        Nuggets    F  23         n/a
# ..                  ...                                ...          ...
# 251         Memphis, TN                          Tennessee           US
# 94         Copiague, NY                           New York           US
# 493         Roanoke, VA                           Virginia           US
# 60        Peekskill, NY                           New York           US
# 248     San Antonio, TX                              Texas           US
# 64           Orange, NJ                         New Jersey           Us
# 435      Norristown, PA                       Pennsylvania           US
# 455      Alexandria, VA                           Virginia           US
# 72                  n/a                                n/a        Sudan
# 458        Stockton, CA                         California           US
# 460           The Hague                      South Holland  Netherlands
# 417         Maryborough                           Victoria    Australia
# 465          Encino, CA                         California           US
# 412     Tallahassee, FL                            Florida           US
# 317              Niksic                                n/a   Yugoslavia
# 259              Luanda                                n/a       Angola
# 405       Lancaster, CA                         California           US
# 83     Melrose Park, IL                           Illinois           US
# 234  Stone Mountain, GA                            Georgia           US
# 231         Memphis, TN                          Tennessee           US
# 33            Provo, UT                               Utah           US
# 32        Oskaloosa, IA                               Iowa           US
# 397       Milwaukee, WI                          Wisconsin           US
# 224          Boston, MA                     Massachussetts           US
# 482         Chicago, IL                           Illinois           US
# 250         Decatur, GA                            Georgia           US
# 379      Valparaiso, IN                            Indiana           US
# 213       Milwaukee, WI                          Wisconsin           US
# 496         Cheyene, WY                            Wyoming           US
# 254       Charlotte, NC                     North Carolina           US
#
#       Race HS Only
# 44   Black      No
# 132  Black      No
# 148  Black      No
# 93   White      No
# 238  Black      No
# 319  White      No
# 191  Black      No
# 483  Black      No
# 186  Black      No
# 274  Mixed      No
# 26   Black      No
# 252  Black      No
# 363  Black      No
# 384  Black      No
# 408  Black      No
# 218  Black      No
# 442  Black      No
# 87   White      No
# 46   Black      No
# 387  Black      No
# 481  Black      No
# 338  Black      No
# 503  Black      No
# 451  Black      No
# 22   Black      No
# 241  Black      No
# 54   Black      No
# 293  White      No
# 369  Black      No
# 376  Black      No
# ..     ...     ...
# 251  Black      No
# 94   Black      No
# 493  Black      No
# 60   Black      No
# 248  Black      No
# 64   Black      No
# 435  Black      No
# 455  Black      No
# 72   Black      No
# 458  Black      No
# 460  White      No
# 417  White      No
# 465  Black      No
# 412  Black      No
# 317  White      No
# 259  Black      No
# 405  Black      No
# 83   Black      No
# 234  Black      No
# 231  Black      No
# 33   Black      No
# 32   Black      No
# 397  Black      No
# 224  White      No
# 482  Black      No
# 250  Black      No
# 379  White      No
# 213  Black      No
# 496  Black      No
# 254  Black      No
#
# [528 rows x 17 columns]

# %% [markdown]
# <img src="...:image/jpeg;base64,...">

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 17 columns):
# Name                                  528 non-null object
# Age                                   528 non-null int64
# Team                                  528 non-null object
# POS                                   528 non-null object
# #                                     528 non-null object
# 2013 $                                528 non-null object
# Ht (In.)                              528 non-null int64
# WT                                    528 non-null int64
# EXP                                   528 non-null int64
# 1st Year                              528 non-null int64
# DOB                                   528 non-null object
# School                                528 non-null object
# City                                  528 non-null object
# State (Province, Territory, Etc..)    528 non-null object
# Country                               528 non-null object
# Race                                  527 non-null object
# HS Only                               528 non-null object
# dtypes: int64(5), object(12)
# memory usage: 70.2+ KB

# %%
nba.plot(kind="barh", x="Name", y="2013 $")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-4b2c8c2f1b16> in <module>()
# ----> 1 nba.plot(kind="barh", x="Name", y="2013 $")
#
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3738                           fontsize=fontsize, colormap=colormap, table=table,
#    3739                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3740                           sort_columns=sort_columns, **kwds)
#    3741     __call__.__doc__ = plot_frame.__doc__
#    3742
#
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2612                  yerr=yerr, xerr=xerr,
#    2613                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2614                  **kwds)
#    2615
#    2616
#
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2439         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2440
# -> 2441     plot_obj.generate()
#    2442     plot_obj.draw()
#    2443     return plot_obj.result
#
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#    1024     def generate(self):
#    1025         self._args_adjust()
# -> 1026         self._compute_plot_data()
#    1027         self._setup_subplots()
#    1028         self._make_plot()
#
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/pandas/tools/plotting.py in _compute_plot_data(self)
#    1133         if is_empty:
#    1134             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1135                             'plot'.format(numeric_data.__class__.__name__))
#    1136
#    1137         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
million_dollar_string = "$1,000,000"

# %%
# million_dollar_string = int(million_dollar_string[1:].replace(',',''))

# %%
million_dollar_string.replace(',','').replace('$','')
# Out:
# '1000000'

# %%
# million_dollar_string.strip("$") # can be applied to string

# %%
str(nba['2013 $'])
# Out:
# '0       $3,250,000\n1      $10,105,855\n2       $2,652,000\n3         $762,195\n4      $11,046,000\n5       $1,246,680\n6       $5,000,000\n7       $5,016,960\n8       $3,563,600\n9       $6,500,000\n10      $3,135,000\n11      $5,625,313\n12             n/a\n13     $12,868,632\n14             n/a\n15        $792,377\n16      $1,750,000\n17     $13,701,250\n18        $510,000\n19        $884,293\n20        $788,872\n21     $21,466,718\n22      $1,186,459\n23        $884,293\n24        $788,872\n25        $788,872\n26      $1,082,520\n27      $4,469,548\n28        $490,180\n29      $1,399,507\n          ...     \n498    $18,668,431\n499     $8,000,000\n500       $951,463\n501    $10,361,446\n502     $6,500,000\n503     $1,160,040\n504            n/a\n505       $884,293\n506     $2,016,000\n507     $2,678,640\n508       $225,479\n509       $788,872\n510       $788,872\n511     $2,317,920\n512     $3,202,920\n513       $854,389\n514            n/a\n515       $884,293\n516     $6,500,000\n517     $6,500,000\n518     $1,660,257\n519     $5,225,000\n520       $490,180\n521       $490,180\n522     $2,676,000\n523       $900,000\n524       $788,872\n525       $854,389\n526    $12,000,000\n527     $2,162,419\nName: 2013 $, dtype: object'

# %%
nba['2013 $'].str

# %%
#need to convert two a string immediately before replacing 
nba["2013 $"].str.replace(",", "").str.replace("$", "").head()
# Out:
# 0     3250000
# 1    10105855
# 2     2652000
# 3      762195
# 4    11046000
# Name: 2013 $, dtype: object

# %%
nba["2013 $"].head()
# Out:
# 0     $3,250,000
# 1    $10,105,855
# 2     $2,652,000
# 3       $762,195
# 4    $11,046,000
# Name: 2013 $, dtype: object

# %%
money_players = nba[nba['2013 $'] != 'n/a']
money_players
# Out:
#                    Name  Age           Team  POS   #       2013 $  Ht (In.)  \
# 0           Gee, Alonzo   26      Cavaliers    F  33   $3,250,000        78
# 1       Wallace, Gerald   31        Celtics    F  45  $10,105,855        79
# 2          Williams, Mo   30  Trail Blazers    G  25   $2,652,000        73
# 3     Gladness, Mickell   27          Magic    C  40     $762,195        83
# 4    Jefferson, Richard   33           Jazz    F  44  $11,046,000        79
# 5         Hill, Solomon   22         Pacers    F   9   $1,246,680        79
# 6       Budinger, Chase   25   Timberwolves    F  10   $5,000,000        79
# 7     Williams, Derrick   22   Timberwolves    F   7   $5,016,960        80
# 8          Hill, Jordan   26         Lakers  F/C  27   $3,563,600        82
# 9        Frye, Channing   30           Suns  F/C   8   $6,500,000        83
# 10      Bayless, Jerryd   25      Grizzlies    G   7   $3,135,000        75
# 11         Terry, Jason   36           Nets    G  31   $5,625,313        74
# 13      Iguodala, Andre   29       Warriors  G/F   9  $12,868,632        78
# 15           Diogu, Ike   29         Knicks  F/C  50     $792,377        80
# 16          Ayres, Jeff   26          Spurs  F/C  11   $1,750,000        81
# 17        Harden, James   24        Rockets    G  13  $13,701,250        77
# 18       Felix, Carrick   23      Cavaliers  G/F  30     $510,000        78
# 19       Pargo, Jannero   33        Bobcats    G   5     $884,293        73
# 20    Beverley, Patrick   25        Rockets    G   2     $788,872        73
# 21         Johnson, Joe   32           Nets  G/F   7  $21,466,718        79
# 22       Brewer, Ronnie   28        Rockets  G/F  10   $1,186,459        79
# 23        Fisher, Derek   39        Thunder    G   6     $884,293        73
# 24       Miller, Quincy   20        Nuggets    F  30     $788,872        81
# 25          Acy, Quincy   23        Raptors    F   4     $788,872        79
# 26         Jones, Perry   22        Thunder    F   3   $1,082,520        83
# 27           Udoh, Ekpe   26          Bucks  F/C   5   $4,469,548        82
# 28           Clark, Ian   22           Jazz    G  21     $490,180        75
# 29      Andersen, Chris   35           Heat  F/C  11   $1,399,507        82
# 30      Jackson, Reggie   23        Thunder    G  15   $1,260,360        75
# 31        Dudley, Jared   28       Clippers  G/F   9   $4,250,000        79
# ..                  ...  ...            ...  ...  ..          ...       ...
# 495    Williams, Reggie   27        Rockets  G/F  55     $947,907        78
# 497    Aminu, Al-Farouq   23       Pelicans    F   0   $3,749,602        81
# 498         Paul, Chris   28       Clippers    G   3  $18,668,431        72
# 499        Teague, Jeff   25          Hawks    G   0   $8,000,000        74
# 500          Smith, Ish   25           Suns    G  30     $951,463        72
# 501         Duncan, Tim   37          Spurs  F/C  21  $10,361,446        83
# 502      Hawes, Spencer   25          76ers    C   0   $6,500,000        85
# 503        Wroten, Tony   20          76ers    G   8   $1,160,040        78
# 505      Thomas, Isaiah   24          Kings    G  22     $884,293        69
# 506      Robinson, Nate   29        Nuggets    G  10   $2,016,000        69
# 507      Ross, Terrence   22        Raptors    G  31   $2,678,640        78
# 508   Pondexter, Quincy   25      Grizzlies  G/F  20     $225,479        78
# 509     Holiday, Justin   24           Jazz  G/F  22     $788,872        78
# 510        Baynes, Aron   26          Spurs  F/C  16     $788,872        82
# 511      Thompson, Klay   23       Warriors  G/F  11   $2,317,920        79
# 512     Lillard, Damian   23  Trail Blazers    G   0   $3,202,920        75
# 513      Alexander, Joe   26       Warriors    F  25     $854,389        80
# 506                         Washington              US  Black      No
# 507                             Oregon              US  Black      No
# 508                         California              US  Black      No
# 509                         California              US  Black      No
# 510                                n/a     New Zealand  White      No
# 511                         California              US  Mixed      No
# 512                         California              US  Black      No
# 513                                n/a          Taiwan  White      No
# 515                           New York              US  Black      No
# 516                         California              US  Black     Yes
# 517                               Ohio              US  Mixed      No
# 518                           Arkansas              US  Black      No
# 519                            Indiana              US  Black      No
# 520                                n/a          Israel  White      No
# 521                              Texas              US  Black      No
# 522                          Wisconsin              US  White      No
# 523                          Minnesota              US  White      No
# 524                          Wisconsin              US  Black      No
# 525                          Wisconsin              US  Black      No
# 526                         New Jersey              US  Black      No
# 527                           Michigan              US  Black      No
#
# [485 rows x 17 columns]

# %%
money_players['salary'] = money_players['2013 $'].str.replace(",", "").str.replace("$", "").astype(int)
# Out:
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
money_players.head()
# Out:
#                  Name  Age           Team POS   #       2013 $  Ht (In.)   WT  \
# 0         Gee, Alonzo   26      Cavaliers   F  33   $3,250,000        78  219
# 1     Wallace, Gerald   31        Celtics   F  45  $10,105,855        79  220
# 2        Williams, Mo   30  Trail Blazers   G  25   $2,652,000        73  195
# 3   Gladness, Mickell   27          Magic   C  40     $762,195        83  220
# 4  Jefferson, Richard   33           Jazz   F  44  $11,046,000        79  230
#
#    EXP  1st Year         DOB       School               City  \
# 0    4      2009   5/29/1987      Alabama  Riviera Beach, FL
# 1   12      2001   7/23/1982      Alabama      Sylacauga, AL
# 2   10      2003  12/19/1982      Alabama        Jackson, MS
# 3    2      2011   7/26/1986  Alabama A&M     Birmingham, AL
# 4   12      2001   6/21/1980      Arizona    Los Angeles, CA
#
#   State (Province, Territory, Etc..) Country   Race HS Only    salary
# 0                            Florida      US  Black      No   3250000
# 1                            Alabama      US  Black      No  10105855
# 2                        Mississippi      US  Black      No   2652000
# 3                            Alabama      US  Black      No    762195
# 4                         California      US  Black      No  11046000

# %%
money_players.groupby("POS").plot(kind='bar', y='salary')
# Out:
# POS
# C      Axes(0.125,0.125;0.775x0.775)
# F      Axes(0.125,0.125;0.775x0.775)
# F/C    Axes(0.125,0.125;0.775x0.775)
# G      Axes(0.125,0.125;0.775x0.775)
# G/F    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
money_players.plot(kind='scatter', x='Age', y='salary', alpha=0.2)

# %%
money_players.columns

# %%
money_players.plot(kind='scatter', x='Ht (In.)', y='WT', alpha = 0.2)

# %%
money_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485 entries, 0 to 527
# Data columns (total 18 columns):
# Name                                  485 non-null object
# Age                                   485 non-null int64
# Team                                  485 non-null object
# POS                                   485 non-null object
# #                                     485 non-null object
# 2013 $                                485 non-null object
# Ht (In.)                              485 non-null int64
# WT                                    485 non-null int64
# EXP                                   485 non-null int64
# 1st Year                              485 non-null int64
# DOB                                   485 non-null object
# School                                485 non-null object
# City                                  485 non-null object
# State (Province, Territory, Etc..)    485 non-null object
# Country                               485 non-null object
# Race                                  484 non-null object
# HS Only                               485 non-null object
# salary                                485 non-null object
# dtypes: int64(5), object(13)
# memory usage: 72.0+ KB
